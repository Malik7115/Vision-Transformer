# %%
import os
import glob
import torch 
pathname ='/home/ibrahim/Projects/Datasets/ViT'

# %%
for f in glob.glob(pathname + '/*', recursive=True):
    print(f)
# Out:
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0015.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0031.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0013.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0040.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0026.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0017.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0002.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0006.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0034.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0036.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0037.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0025.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0016.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0023.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0042.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0022.jpg
# /home/ibrahim/Projects/Datasets/ViT/ant/image_0019.jpg
# ...
